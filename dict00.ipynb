# %% [markdown]
# <a href="https://colab.research.google.com/github/shivampatle2004/python_pratice/blob/main/dict00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1: Key with maximum unique values
# Given a dictionary with values list, extract key whose value has most unique values.
#
# Example 1:
#
# Input:
#
# test_dict = {"CampusX" : [5, 7, 9, 4, 0], "is" : [6, 7, 4, 3, 3], "Best" : [9, 9, 6, 5, 5]}
# Output:
#
# CampusX

# %%
d = {"CampusX" : [5, 7, 9, 4, 0], "is" : [6, 7, 4, 3, 3], "Best" : [9, 9, 6, 5, 5]}
c={}
c1=0
d1=d.copy()
for i in d :
  c=set(d[i])
  c1=len(c)
  d1[i]=c1
print(d1)
for i in d1:
  for j in d1:
    if d1[i]>d1[j]:
      c1=d1[i]
  break
print(c1)
for i in d1 :
  if d1[i]==c1:
    print(i)
# Out:
# {'CampusX': 5, 'is': 4, 'Best': 3}
# 5
# CampusX

# %%
d={"CampusX" : [5, 7, 7, 7, 7], "is" : [6, 7, 7, 7], "Best" : [9, 9, 6, 5, 5]}

c={}
c1=0
d1=d.copy()
for i in d :
  c=set(d[i])
  c1=len(c)
  d1[i]=c1
print(d1)
for i in d1:
  for j in d1:
    if d1[i]>d1[j]:
      c1=d1[i]
  break
print(c1)
for i in d1 :
  if d1[i]==c1:
    print(i)
# Out:
# {'CampusX': 2, 'is': 2, 'Best': 3}
# 3
# Best

# %% [markdown]
# Replace words from Dictionary. Given String, replace it’s words from lookup dictionary.
# Example 1:
#
# Input:
#
# test_str = 'CampusX best for DS students.'
# repl_dict = {"best" : "is the best channel", "DS" : "Data-Science"}
# Output:
#
# CampusX is the best channel for Data-Science students.

# %%
s = 'CampusX best for DS students.'
d = {"best": "is the best channel", "DS": "Data-Science"}

# Split manually
r = ""
l2 = []

for ch in s:
    if ch == " ":
        l2.append(r)
        r = ""
    else:
        r = r + ch

l2.append(r)

# Replace words
for i in range(len(l2)):
    if l2[i] in d:
        l2[i] = d[l2[i]]

# Join back to sentence
new_sentence = " ".join(l2)

print(new_sentence)
# Out:
# CampusX is the best channel for Data-Science students.

# %% [markdown]
# Convert a list of Tuples into Dictionary.
# Example 1:
#
# Input:
#
# [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
# Output:
#
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}

# %%
l=[("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
s={}
for i in range(len(l)):
  s[l[i][0]]=l[i][1]
print(s)
# Out:
# {'akash': 10, 'gaurav': 12, 'anand': 14, 'suraj': 20, 'akhil': 25, 'ashish': 30}

# %% [markdown]
#  Sort Dictionary key and values List.
# Example 1:
#
# Input:
#
# {'c': [3], 'b': [12, 10], 'a': [19, 4]}
# Output:
#
# {'a': [4, 19], 'b': [10, 12], 'c': [3]}

# %%
s={'c': [3], 'b': [12, 10], 'a': [19, 4]}
s2={}
l=[]
c=0
for i in s:
  l.append(sorted(s[i]))
  s[i]=l[c]
  c=c+1
print(s)
l.clear()
l=sorted(s)
s2={}
c=0
for i in s:
  s2[l[c]]=s[l[c]]
  c=c+1

print(s2)
# Out:
# {'c': [3], 'b': [10, 12], 'a': [4, 19]}
# {'a': [4, 19], 'b': [10, 12], 'c': [3]}

# %%
s={'c': [10, 34, 3]}
s2={}
l=[]
c=0
for i in s:
  l.append(sorted(s[i]))
  s[i]=l[c]
  c=c+1
print(s)
l.clear()
l=sorted(s)
s2={}
c=0
for i in s:
  s2[l[c]]=s[l[c]]
  c=c+1

print(s2)
# Out:
# {'c': [3, 10, 34]}
# {'c': [3, 10, 34]}
