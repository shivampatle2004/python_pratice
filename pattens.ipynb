# %% [markdown]
# <a href="https://colab.research.google.com/github/shivampatle2004/python_pratice/blob/main/pattens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Print the following pattern. Write a program to use for loop to print the following reverse number pattern.
#
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %%
n=int(input("netr the number of rows"))

for i in range(1,n+1):
  for j in range(n,0,-1):
    print(j,end=" ")
  print("\n")
  n=n-1
# Out:
# netr the number of rows5
# 5 4 3 2 1
#
# 4 3 2 1
#
# 3 2 1
#
# 2 1
#
# 1

# %% [markdown]
# Problem 2: Print the following pattern.
# *
# **
# ***
# **
# *

# %%
n=int(input("netr the number of rows"))
for i in range(1,n+1):
  for j in range(0,i):
    print("*",end=" ")
  print("\n")
for i in range(n+1,0,-1):
  for j in range(i,0,-1):
    print("*",end=" ")
  print("\n")
# Out:
# netr the number of rows5
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
#
# * * * * * *
#
# * * * * *
#
# * * * *
#
# * * *
#
# * *
#
# *

# %% [markdown]
# Write a program to pring the following pattern
#     *
#   * * *
# * * * * *

# %%
n=int(input("netr the number of rows"))
for i in range(1,n+1,2):
  for j in range(i,n+1,2):
    print(" ",end=" ")
  for k in range(i):
    print("*",end=" ")
  print("\n")
# Out:
# netr the number of rows8
#         *
#
#       * * *
#
#     * * * * *
#
#   * * * * * * *
