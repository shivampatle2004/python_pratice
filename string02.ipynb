# %% [markdown]
# <a href="https://colab.research.google.com/github/shivampatle2004/python_pratice/blob/main/string02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create Short Form from initial character

# %%
s=input()
r=''
r=r+s[0]
for i in range(1,len(s)):
  if(s[i]==' '):
    r=r+s[i+1]


print(r.upper()  )
# Out:
# Create Short Form from initial character
# CSFFIC

# %% [markdown]
# Append second string in the middle of first string

# %%
s=input()
t=input()
c=0
r=''
n1=len(s)//2
n2=abs(len(s)-n1)
for i in range(0,n1):
  r=r+s[i]
for j in range(n1,n1+len(t)):
  r=r+t[c]
  c=c+1
for k in range(len(t)+n1,len(t)+n1+n2)  :
  i=i+1
  r=r+s[i]
print(r)
# Out:
# rudra
# patle
# rupatledra

# %% [markdown]
# Given string contains a combination of the lower and upper case letters. Write a program to arrange the characters of a string so that all lowercase letters should come first.

# %%
s=input()
r=''
r1=''
for i in s:
  if(i.upper()==i):
    r=r+i
  else:
    r1=r1+i
print(r1+r)
# Out:
# shKIhIvbbhhQ
# shhvbbhhKIIQ

# %% [markdown]
# Take a alphanumeric string input and print the sum and average of the digits that appear in the string, ignoring all other characters.

# %%
s=input()
r=''
for i in s:
 if(i.isdigit()):
  r=r+i
s=0

for j in r:
  s=s+int(j)
av=s/len(r)
print(av)
print(s)
# Out:
# shhi123ff66
# 3.6
# 18

# %% [markdown]
# Removal of all characters from a string except integers

# %%
s=input()
r=''
for i in s:
  if(i.isdigit()):
    r=r+i
print(r)
# Out:
# shivam 20003 jsjsjsjj44jsjjss
# 2000344

# %% [markdown]
# Given a string. the task is to check if the string is symmetrical or not. A string is said to be symmetrical if both the halves of the string are the same.

# %%
s=input()
n=len(s)//2
r=''
t=''
for i in range(0,n):
  r=r+s[i]
if(len(s)%2!=0):
  n=n+1
for j in range(n,len(s)):
  t=t+s[j]
if(t==r):
  print("it is symmetrical")
else:
  print("it is not symmetrical")
# Out:
# khokho
# it is symmetrical

# %% [markdown]
# Statement: We are given a string and we need to reverse words of a given string.

# %%
s=input()
w=s.split()
w.reverse()
print(w)
# Out:
# ds gf vb
# ['vb', 'gf', 'ds']

# %%
s=input()
w=s.split()
for i in range(len(w)-1,-1,-1):
  print(w[i],end=",")
# Out:
# v gg fff jj
# jj,fff,gg,v,

# %% [markdown]
# Given two sentences as strings A and B. The task is to return a list of all uncommon words. A word is uncommon if it appears exactly once in any one of the sentences, and does not appear in the other sentence. Note: A sentence is a string of space-separated words. Each word consists only of lowercase letters.

# %%
s=input()
t=input()

s1=s.split()
t1=t.split()
for i in s1:
  c=0
  for j in t1:
    if(i==j):
      c=c+1
  if(c==0):
    print(i,end=" ")
for k in t1:
  c1=0
  for l in s1:
    if(k==l):
      c1=c1+1
  if(c1==0):
    print(k,end=" ")
# Out:
# cat lion dog
# dog rat lion
# cat rat

# %% [markdown]
# ffind a location of a word in a given sentence.

# %%
s=input()
t=input()
c=0
s1=s.split()
for i in s1:
  c=c+1
  if i==t:
    break
print(c)
# Out:
# s h i v am
# am
# 5

# %% [markdown]
# Write a program that can remove all the duplicate characters from a string. User will provide the input.

# %%
s=input()
w=s.split()
r=''
for i in w:
  if i not in r:
    r=r+i
print(r)
