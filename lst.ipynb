# %% [markdown]
# <a href="https://colab.research.google.com/github/shivampatle2004/python_pratice/blob/main/lst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# starting list
