# %% [markdown]
# <a href="https://colab.research.google.com/github/shivampatle2004/python_pratice/blob/main/string01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Find the length of a given string without using the len() function

# %%
s=input()
c=0
for i in s:
  c=c+1
print(c)
# Out:
# shivam
# 6

# %% [markdown]
# # Extract username from a given email.
# # Eg if the email is nitish24singh@gmail.com
# # then the username should be nitish24singh

# %%
s=input()
c=0
for i in s:
  c=c+1
  if(i=='@'):
    for v in range(0,c-1):
      print(s[v],end="")
# Out:
# shivam@
# shivam

# %% [markdown]
# # Count the frequency of a particular character in a provided string.
# # Eg 'hello how are you' is the string, the frequency of h in this string is 2.

# %%
s=input()
t=input()
c=0
for i in s:
  if(t==i):
    c=c+1
print(c)
# Out:
# shivamh
# h
# 2

# %%
s=input()
s.count('h')
s.index('h')
s.find('h')
# Out:
# ssssh
# 4

# %% [markdown]
# Write a program which can remove a particular character from a string.

# %%
s=input()
t=input()
r=''
for i in s:
  if(t!=i):
    r=r+i
print(r)
# Out:
# shiv
# h
# siv

# %% [markdown]
# # Write a program that can check whether a given string is palindrome or not.
# # abba
# # malayalam

# %%
s=input()
l=len(s)
r=''
for i in s:


  print()
# Out:
# shiavm
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-218001590.py in <cell line: 0>()
#       1 s=input()
#       2 for i in range(len(s),0,-1):
# ----> 3   print(s[i])
#
# IndexError: string index out of range
