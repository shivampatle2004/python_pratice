# %% [markdown]
# <a href="https://colab.research.google.com/github/shivampatle2004/python_pratice/blob/main/sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [5, 2, 8, 1, 3]
l1=[]
for i in range(len(l)):
  l1.append((l.pop(l.index(min(l)))))
print(l1)
# Out:
# [1, 2, 3, 5, 8]
